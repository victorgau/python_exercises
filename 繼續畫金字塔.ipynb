# %% [markdown]
# ## 【練習】
#
# 請寫一函式，讀入一個整數，輸出整數高度的金字塔。
#
# 執行： pyramid(3)
#
# 輸出：
#
#       *
#      ***
#     *****
#
# 執行： pyramid(5)
#
# 輸出：
#
#         *
#        ***
#       *****
#      *******
#     *********

# %%
def pyramid(h):
    pass
