# %% [markdown]
# ## 【練習】
#
# 假設我們用不同的策略，挑出了兩堆股票。
#
# 怎麼找出同時符合兩個策略的股票？

# %%
import pandas as pd

# %%
url = "http://dts.twse.com.tw/opendata/t187ap03_L.csv"

# %%
df = pd.read_csv(url)

# %%
all = df["公司簡稱"]
